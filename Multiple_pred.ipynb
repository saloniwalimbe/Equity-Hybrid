# %%
import math
import random
import datetime
from urllib.request import urlopen
import csv
import warnings
warnings.filterwarnings('ignore')     #suppress unwanted warnings
import numpy as np
import pandas as pd
from scipy.optimize import minimize, Bounds
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('seaborn-whitegrid')

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
from sklearn.metrics import mean_squared_error

# %%
dailynav = 'https://raw.githubusercontent.com/saloniwalimbe/Mutual-Fund-Schemes/main/DailyNAV.csv'

# %%
f = urlopen(dailynav)
data = f.read()
data = data.decode('utf-8')
data = data.split('\n')

list_for_df = []
for line in data[1:]:
  row = line.split(',')
  if row != '':
    list_for_df.append(row)

df = pd.DataFrame(list_for_df, columns= ['NAV_Date',
                                         'Axis_Equity','CanaraRobeco_Bluechip','Franklin_Bluechip','ICICI_FocusedEq','Kotak_Bluechip','Kotak_Flexicap','SBI_Bluechip','SBI_FocusedEq',
                                         'AdityaBirla_EqHybrid','Franklin_EqHybrid','HDFC_EqHybrid','SBI_EqHybrid',
                                         'Kotak_EqArbitrage','SBI_Arbitrage','LIC_Bond','LIC_DebtHybrid'
                                        ]
                 )


df['NAV_Date'] = pd.to_datetime(df['NAV_Date'], infer_datetime_format=True)
df['Axis_Equity'] = pd.to_numeric(df['Axis_Equity'])
df['CanaraRobeco_Bluechip'] = pd.to_numeric(df['CanaraRobeco_Bluechip'])
df['Franklin_Bluechip'] = pd.to_numeric(df['Franklin_Bluechip'])
df['ICICI_FocusedEq'] = pd.to_numeric(df['ICICI_FocusedEq'])
df['Kotak_Bluechip'] = pd.to_numeric(df['Kotak_Bluechip'])
df['Kotak_Flexicap'] = pd.to_numeric(df['Kotak_Flexicap'])
df['SBI_Bluechip'] = pd.to_numeric(df['SBI_Bluechip'], errors = "ignore")
df['SBI_FocusedEq'] = pd.to_numeric(df['SBI_FocusedEq'], errors = "ignore")
df['AdityaBirla_EqHybrid'] = pd.to_numeric(df['AdityaBirla_EqHybrid'], errors = "ignore")
df['Franklin_EqHybrid'] = pd.to_numeric(df['Franklin_EqHybrid'], errors = "ignore")
df['HDFC_EqHybrid'] = pd.to_numeric(df['HDFC_EqHybrid'], errors = "ignore")
df['SBI_EqHybrid'] = pd.to_numeric(df['SBI_EqHybrid'], errors = "ignore")
df['Kotak_EqArbitrage'] = pd.to_numeric(df['Kotak_EqArbitrage'], errors = "ignore")
df['SBI_Arbitrage'] = pd.to_numeric(df['SBI_Arbitrage'], errors = "ignore")
df['LIC_Bond'] = pd.to_numeric(df['LIC_Bond'], errors = "ignore")
df['LIC_DebtHybrid'] = pd.to_numeric(df['LIC_DebtHybrid'], errors = "ignore")


df = df.set_index('NAV_Date')

df = df.dropna()

# %%
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
list_of_mf = ['Axis_Equity', 'CanaraRobeco_Bluechip', 'Franklin_Bluechip',
       'ICICI_FocusedEq', 'Kotak_Bluechip', 'Kotak_Flexicap', 'SBI_Bluechip',
       'SBI_FocusedEq', 'AdityaBirla_EqHybrid', 'Franklin_EqHybrid',
       'HDFC_EqHybrid', 'SBI_EqHybrid', 'Kotak_EqArbitrage', 'SBI_Arbitrage',
       'LIC_Bond', 'LIC_DebtHybrid']

# %%
df_ = {}
for i in list_of_mf:
  df_[i] = df[i]

# %%
def split(dataframe, border):
    return dataframe.loc[:border,], dataframe.loc[border:,]

# %%
df_new = {}
for i in list_of_mf:
    df_new[i] = {}
    #df_new[i]['Train'], df_new[i]["Test"] = int(len(df_)*0.75), (int(len(df_)*0.25))
    df_new[i]['Train'], df_new[i]["Test"] = split(df_[i], pd.to_datetime('2019-01-01'))

# %%
for i in list_of_mf:
    plt.figure(figsize=(14,4))
    plt.plot(df_new[i]["Train"])
    plt.plot(df_new[i]["Test"])
    plt.ylabel("NAV")
    plt.xlabel("Date")
    plt.legend(["Training Set", "Test Set"])
    plt.title(i + " NAV")

# %%
# Scaling the training set
transform_train = {}
transform_test = {}
scaler = {}

for num, i in enumerate(list_of_mf):
    sc = MinMaxScaler(feature_range=(0,1))
    a0 = np.array(df_new[i]["Train"])
    a1 = np.array(df_new[i]["Test"])
    a0 = a0.reshape(a0.shape[0],1)
    a1 = a1.reshape(a1.shape[0],1)
    transform_train[i] = sc.fit_transform(a0)
    transform_test[i] = sc.fit_transform(a1)
    scaler[i] = sc

del a0
del a1

# %%
for i in transform_train.keys():
    print(i, transform_train[i].shape)
print("\n")    
for i in transform_test.keys():
    print(i, transform_test[i].shape)
# Out:
# Axis_Equity (1475, 1)
# CanaraRobeco_Bluechip (1475, 1)
# Franklin_Bluechip (1475, 1)
# ICICI_FocusedEq (1475, 1)
# Kotak_Bluechip (1475, 1)
# Kotak_Flexicap (1475, 1)
# SBI_Bluechip (1475, 1)
# SBI_FocusedEq (1475, 1)
# AdityaBirla_EqHybrid (1475, 1)
# Franklin_EqHybrid (1475, 1)
# HDFC_EqHybrid (1475, 1)
# SBI_EqHybrid (1475, 1)
# Kotak_EqArbitrage (1475, 1)
# SBI_Arbitrage (1475, 1)
# LIC_Bond (1475, 1)
# LIC_DebtHybrid (1475, 1)
#
#
# Axis_Equity (986, 1)
# CanaraRobeco_Bluechip (986, 1)
# Franklin_Bluechip (986, 1)
# ICICI_FocusedEq (986, 1)
# Kotak_Bluechip (986, 1)
# Kotak_Flexicap (986, 1)
# SBI_Bluechip (986, 1)
# SBI_FocusedEq (986, 1)
# AdityaBirla_EqHybrid (986, 1)
# Franklin_EqHybrid (986, 1)
# HDFC_EqHybrid (986, 1)
# SBI_EqHybrid (986, 1)
# Kotak_EqArbitrage (986, 1)
# SBI_Arbitrage (986, 1)
# LIC_Bond (986, 1)
# LIC_DebtHybrid (986, 1)

# %%
trainset = {}
testset = {}
for j in list_of_mf:
    trainset[j] = {}
    X_train = []
    y_train = []
    for i in range(120,1475):
        X_train.append(transform_train[j][i-120:i,0])
        y_train.append(transform_train[j][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset[j]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset[j]["y"] = y_train
    
    testset[j] = {}
    X_test = []
    y_test = []    
    for i in range(120, 986):
        X_test.append(transform_test[j][i-120:i,0])
        y_test.append(transform_test[j][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset[j]["X"] = np.reshape(X_test, (X_test.shape[0], X_train.shape[1], 1))
    testset[j]["y"] = y_test

# %%
arr_buff = []
for i in list_of_mf:
    buff = {}
    buff["X_train"] = trainset[i]["X"].shape
    buff["y_train"] = trainset[i]["y"].shape
    buff["X_test"] = testset[i]["X"].shape
    buff["y_test"] = testset[i]["y"].shape
    arr_buff.append(buff)

pd.DataFrame(arr_buff, index=list_of_mf)
# Out:
#                               X_train  y_train         X_test  y_test
# Axis_Equity            (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# CanaraRobeco_Bluechip  (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# Franklin_Bluechip      (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# ICICI_FocusedEq        (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# Kotak_Bluechip         (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# Kotak_Flexicap         (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# SBI_Bluechip           (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# SBI_FocusedEq          (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# AdityaBirla_EqHybrid   (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# Franklin_EqHybrid      (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# HDFC_EqHybrid          (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# SBI_EqHybrid           (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# Kotak_EqArbitrage      (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# SBI_Arbitrage          (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# LIC_Bond               (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)
# LIC_DebtHybrid         (1355, 120, 1)  (1355,)  (866, 120, 1)  (866,)

# %%
# %%time
# The LSTM architecture
regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.5))
# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.5))
# The output layer
regressor.add(Dense(units=1))

# Compiling the RNN
regressor.compile(optimizer='rmsprop', loss='mean_squared_error')
# Fitting to the training set
for i in list_of_mf:
    print("Fitting to", i)
    regressor.fit(trainset[i]["X"], trainset[i]["y"], epochs=10, batch_size=200)
# Out:
# Fitting to Axis_Equity
# Epoch 1/10
# 7/7 [==============================] - 16s 1s/step - loss: 0.1084
# Epoch 2/10
# 7/7 [==============================] - 6s 813ms/step - loss: 0.0307
# Epoch 3/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0308
# Epoch 4/10
# 7/7 [==============================] - 6s 823ms/step - loss: 0.0269
# Epoch 5/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0179
# Epoch 6/10
# 7/7 [==============================] - 6s 816ms/step - loss: 0.0220
# Epoch 7/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0271
# Epoch 8/10
# 7/7 [==============================] - 6s 820ms/step - loss: 0.0152
# Epoch 9/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0224
# Epoch 10/10
# 7/7 [==============================] - 6s 829ms/step - loss: 0.0233
# Fitting to CanaraRobeco_Bluechip
# Epoch 1/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0154
# Epoch 2/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0174
# Epoch 3/10
# 7/7 [==============================] - 6s 833ms/step - loss: 0.0170
# Epoch 4/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0154
# Epoch 5/10
# 7/7 [==============================] - 6s 832ms/step - loss: 0.0156
# Epoch 6/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0181
# Epoch 7/10
# 7/7 [==============================] - 6s 836ms/step - loss: 0.0160
# Epoch 8/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0137
# Epoch 9/10
# 7/7 [==============================] - 6s 829ms/step - loss: 0.0159
# Epoch 10/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0158
# Fitting to Franklin_Bluechip
# Epoch 1/10
# 7/7 [==============================] - 6s 831ms/step - loss: 0.0177
# Epoch 2/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0197
# Epoch 3/10
# 7/7 [==============================] - 6s 829ms/step - loss: 0.0124
# Epoch 4/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0165
# Epoch 5/10
# 7/7 [==============================] - 6s 830ms/step - loss: 0.0147
# Epoch 6/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0147
# Epoch 7/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0154
# Epoch 8/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0135
# Epoch 9/10
# 7/7 [==============================] - 6s 833ms/step - loss: 0.0137
# Epoch 10/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0151
# Fitting to ICICI_FocusedEq
# Epoch 1/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0124
# Epoch 2/10
# 7/7 [==============================] - 6s 834ms/step - loss: 0.0097
# Epoch 3/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0175
# Epoch 4/10
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0083
# Epoch 5/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0150
# Epoch 6/10
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0103
# Epoch 7/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0123
# Epoch 8/10
# 7/7 [==============================] - 6s 833ms/step - loss: 0.0119
# Epoch 9/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0128
# Epoch 10/10
# 7/7 [==============================] - 6s 828ms/step - loss: 0.0091
# Fitting to Kotak_Bluechip
# Epoch 1/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0138
# Epoch 2/10
# 7/7 [==============================] - 6s 840ms/step - loss: 0.0105
# Epoch 3/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0108
# Epoch 4/10
# 7/7 [==============================] - 6s 834ms/step - loss: 0.0134
# Epoch 5/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0101
# Epoch 6/10
# 7/7 [==============================] - 6s 831ms/step - loss: 0.0102
# Epoch 7/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0123
# Epoch 8/10
# 7/7 [==============================] - 6s 831ms/step - loss: 0.0103
# Epoch 9/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0079
# Epoch 10/10
# 7/7 [==============================] - 6s 840ms/step - loss: 0.0144
# Fitting to Kotak_Flexicap
# Epoch 1/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0090
# Epoch 2/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0100
# Epoch 3/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0111
# Epoch 4/10
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0086
# Epoch 5/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0106
# Epoch 6/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0096
# Epoch 7/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0074
# Epoch 8/10
# 7/7 [==============================] - 6s 824ms/step - loss: 0.0101
# Epoch 9/10
# 7/7 [==============================] - 7s 998ms/step - loss: 0.0075
# Epoch 10/10
# 7/7 [==============================] - 6s 833ms/step - loss: 0.0115
# Fitting to SBI_Bluechip
# Epoch 1/10
# 7/7 [==============================] - 7s 988ms/step - loss: 0.0110
# Epoch 2/10
# 7/7 [==============================] - 6s 829ms/step - loss: 0.0107
# Epoch 3/10
# 7/7 [==============================] - 7s 976ms/step - loss: 0.0091
# Epoch 4/10
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0115
# Epoch 5/10
# 7/7 [==============================] - 7s 969ms/step - loss: 0.0106
# Epoch 6/10
# 7/7 [==============================] - 6s 822ms/step - loss: 0.0075
# Epoch 7/10
# 7/7 [==============================] - 7s 950ms/step - loss: 0.0107
# Epoch 8/10
# 7/7 [==============================] - 6s 821ms/step - loss: 0.0111
# Epoch 9/10
# 7/7 [==============================] - 7s 958ms/step - loss: 0.0071
# Epoch 10/10
# 7/7 [==============================] - 6s 823ms/step - loss: 0.0109
# Fitting to SBI_FocusedEq
# Epoch 1/10
# 7/7 [==============================] - 6s 838ms/step - loss: 0.0073
# Epoch 2/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0080
# Epoch 3/10
# 7/7 [==============================] - 6s 823ms/step - loss: 0.0076
# Epoch 4/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0094
# Epoch 5/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0063
# Epoch 6/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0089
# Epoch 7/10
# 7/7 [==============================] - 6s 828ms/step - loss: 0.0068
# Epoch 8/10
# 7/7 [==============================] - 7s 979ms/step - loss: 0.0065
# Epoch 9/10
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0098
# Epoch 10/10
# 7/7 [==============================] - 7s 963ms/step - loss: 0.0069
# Fitting to AdityaBirla_EqHybrid
# Epoch 1/10
# 7/7 [==============================] - 6s 831ms/step - loss: 0.0099
# Epoch 2/10
# 7/7 [==============================] - 7s 930ms/step - loss: 0.0085
# Epoch 3/10
# 7/7 [==============================] - 6s 842ms/step - loss: 0.0090
# Epoch 4/10
# 7/7 [==============================] - 7s 914ms/step - loss: 0.0089
# Epoch 5/10
# 7/7 [==============================] - 6s 879ms/step - loss: 0.0073
# Epoch 6/10
# 7/7 [==============================] - 7s 885ms/step - loss: 0.0095
# Epoch 7/10
# 7/7 [==============================] - 6s 906ms/step - loss: 0.0100
# Epoch 8/10
# 7/7 [==============================] - 7s 850ms/step - loss: 0.0085
# Epoch 9/10
# 7/7 [==============================] - 6s 911ms/step - loss: 0.0097
# Epoch 10/10
# 7/7 [==============================] - 7s 843ms/step - loss: 0.0064
# Fitting to Franklin_EqHybrid
# Epoch 1/10
# 7/7 [==============================] - 7s 946ms/step - loss: 0.0105
# Epoch 2/10
# 7/7 [==============================] - 7s 824ms/step - loss: 0.0088
# Epoch 3/10
# 7/7 [==============================] - 7s 959ms/step - loss: 0.0061
# Epoch 4/10
# 7/7 [==============================] - 6s 827ms/step - loss: 0.0104
# Epoch 5/10
# 7/7 [==============================] - 7s 973ms/step - loss: 0.0075
# Epoch 6/10
# 7/7 [==============================] - 6s 825ms/step - loss: 0.0078
# Epoch 7/10
# 7/7 [==============================] - 7s 986ms/step - loss: 0.0081
# Epoch 8/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0086
# Epoch 9/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0066
# Epoch 10/10
# 7/7 [==============================] - 6s 824ms/step - loss: 0.0088
# Fitting to HDFC_EqHybrid
# Epoch 1/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0059
# Epoch 2/10
# 7/7 [==============================] - 6s 825ms/step - loss: 0.0075
# Epoch 3/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0059
# Epoch 4/10
# 7/7 [==============================] - 6s 824ms/step - loss: 0.0078
# Epoch 5/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0058
# Epoch 6/10
# 7/7 [==============================] - 6s 826ms/step - loss: 0.0063
# Epoch 7/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0061
# Epoch 8/10
# 7/7 [==============================] - 6s 831ms/step - loss: 0.0066
# Epoch 9/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0070
# Epoch 10/10
# 7/7 [==============================] - 6s 825ms/step - loss: 0.0062
# Fitting to SBI_EqHybrid
# Epoch 1/10
# 7/7 [==============================] - 6s 814ms/step - loss: 0.0067
# Epoch 2/10
# 7/7 [==============================] - 6s 939ms/step - loss: 0.0066
# Epoch 3/10
# 7/7 [==============================] - 7s 818ms/step - loss: 0.0070
# Epoch 4/10
# 7/7 [==============================] - 6s 915ms/step - loss: 0.0058
# Epoch 5/10
# 7/7 [==============================] - 7s 830ms/step - loss: 0.0057
# Epoch 6/10
# 7/7 [==============================] - 6s 936ms/step - loss: 0.0080
# Epoch 7/10
# 7/7 [==============================] - 7s 816ms/step - loss: 0.0053
# Epoch 8/10
# 7/7 [==============================] - 6s 911ms/step - loss: 0.0080
# Epoch 9/10
# 7/7 [==============================] - 7s 843ms/step - loss: 0.0057
# Epoch 10/10
# 7/7 [==============================] - 6s 926ms/step - loss: 0.0057
# Fitting to Kotak_EqArbitrage
# Epoch 1/10
# 7/7 [==============================] - 6s 876ms/step - loss: 0.0050
# Epoch 2/10
# 7/7 [==============================] - 7s 880ms/step - loss: 0.0060
# Epoch 3/10
# 7/7 [==============================] - 6s 862ms/step - loss: 0.0049
# Epoch 4/10
# 7/7 [==============================] - 7s 878ms/step - loss: 0.0054
# Epoch 5/10
# 7/7 [==============================] - 6s 870ms/step - loss: 0.0046
# Epoch 6/10
# 7/7 [==============================] - 7s 880ms/step - loss: 0.0048
# Epoch 7/10
# 7/7 [==============================] - 6s 877ms/step - loss: 0.0059
# Epoch 8/10
# 7/7 [==============================] - 7s 859ms/step - loss: 0.0036
# Epoch 9/10
# 7/7 [==============================] - 6s 881ms/step - loss: 0.0042
# Epoch 10/10
# 7/7 [==============================] - 7s 864ms/step - loss: 0.0059
# Fitting to SBI_Arbitrage
# Epoch 1/10
# 7/7 [==============================] - 7s 943ms/step - loss: 0.0040
# Epoch 2/10
# 7/7 [==============================] - 6s 825ms/step - loss: 0.0037
# Epoch 3/10
# 7/7 [==============================] - 7s 932ms/step - loss: 0.0050
# Epoch 4/10
# 7/7 [==============================] - 6s 828ms/step - loss: 0.0052
# Epoch 5/10
# 7/7 [==============================] - 7s 936ms/step - loss: 0.0050
# Epoch 6/10
# 7/7 [==============================] - 6s 818ms/step - loss: 0.0048
# Epoch 7/10
# 7/7 [==============================] - 7s 932ms/step - loss: 0.0041
# Epoch 8/10
# 7/7 [==============================] - 6s 820ms/step - loss: 0.0042
# Epoch 9/10
# 7/7 [==============================] - 7s 935ms/step - loss: 0.0047
# Epoch 10/10
# 7/7 [==============================] - 6s 815ms/step - loss: 0.0045
# Fitting to LIC_Bond
# Epoch 1/10
# 7/7 [==============================] - 6s 818ms/step - loss: 0.0050
# Epoch 2/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0064
# Epoch 3/10
# 7/7 [==============================] - 6s 818ms/step - loss: 0.0043
# Epoch 4/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0043
# Epoch 5/10
# 7/7 [==============================] - 6s 823ms/step - loss: 0.0055
# Epoch 6/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0059
# Epoch 7/10
# 7/7 [==============================] - 6s 815ms/step - loss: 0.0043
# Epoch 8/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0057
# Epoch 9/10
# 7/7 [==============================] - 6s 821ms/step - loss: 0.0049
# Epoch 10/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0051
# Fitting to LIC_DebtHybrid
# Epoch 1/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0057
# Epoch 2/10
# 7/7 [==============================] - 6s 818ms/step - loss: 0.0050
# Epoch 3/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0060
# Epoch 4/10
# 7/7 [==============================] - 6s 823ms/step - loss: 0.0051
# Epoch 5/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0042
# Epoch 6/10
# 7/7 [==============================] - 6s 829ms/step - loss: 0.0060
# Epoch 7/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0049
# Epoch 8/10
# 7/7 [==============================] - 6s 821ms/step - loss: 0.0043
# Epoch 9/10
# 7/7 [==============================] - 7s 1s/step - loss: 0.0061
# Epoch 10/10
# 7/7 [==============================] - 6s 824ms/step - loss: 0.0046
# CPU times: user 26min 50s, sys: 1min 32s, total: 28min 22s
# Wall time: 20min 8s

# %%
pred_result = {}
for i in list_of_mf:
    y_true = scaler[i].inverse_transform(testset[i]["y"].reshape(-1,1))
    y_pred = scaler[i].inverse_transform(regressor.predict(testset[i]["X"]))
    MSE = mean_squared_error(y_true, y_pred)
    pred_result[i] = {}
    pred_result[i]["True"] = y_true
    pred_result[i]["Pred"] = y_pred
    
    plt.figure(figsize=(14,6))
    plt.title("{} with MSE {:10.4f}".format(i,MSE))
    plt.plot(y_true)
    plt.plot(y_pred)
# Out:
# 28/28 [==============================] - 4s 69ms/step
# 28/28 [==============================] - 2s 68ms/step
# 28/28 [==============================] - 2s 68ms/step
# 28/28 [==============================] - 2s 87ms/step
# 28/28 [==============================] - 2s 67ms/step
# 28/28 [==============================] - 2s 68ms/step
# 28/28 [==============================] - 2s 67ms/step
# 28/28 [==============================] - 2s 68ms/step
# 28/28 [==============================] - 3s 101ms/step
# 28/28 [==============================] - 2s 68ms/step
# 28/28 [==============================] - 2s 67ms/step
# 28/28 [==============================] - 2s 67ms/step
# 28/28 [==============================] - 2s 67ms/step
# 28/28 [==============================] - 2s 86ms/step
# 28/28 [==============================] - 2s 80ms/step
# 28/28 [==============================] - 2s 66ms/step
